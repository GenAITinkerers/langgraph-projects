# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict

# %%
class BatsmanState(TypedDict):
    runs:int
    balls: int
    fours:int
    sixes:int

    sr:float        # strike rate
    bpb:float       # number of ball per boundary
    boundary_percentage:float    # total run by boundary out of total run in percentage
    summary:str

# %%
def calculate_sr(state:BatsmanState):
    sr = (state['run'] / state['balls']) * 100
    return {'sr':sr}

# %%
def calculate_bpb(state:BatsmanState):
    bpb = state['balls'] / (state['fours'] + state['sixes'])
    return {'bpb':bpb}

# %%
def calculate_boundary_percentage(state:BatsmanState):
    boundary_percentage = (((state['fours'] *4) + (state['sixes'] *6)) / state['runs']) *100
    return {'boundary_percent':boundary_percentage}

# %%
def summary1(state:BatsmanState):
    summary = f"""
                Strike Rate - {state['sr']} \n
                Balls per boundary - {state['bpb']} \n
                Boundary Percent - {state['boundary_percentage']}
               """
    return {'summary':summary}

# %%
graph = StateGraph(BatsmanState)
graph.add_node('calculate_sr', calculate_sr)
graph.add_node('calculate_bpb', calculate_bpb)
graph.add_node('calculate_boundary_percentage', calculate_boundary_percentage)
graph.add_node('summary1', summary1)

graph.add_edge(START, 'calculate_sr')
graph.add_edge(START, 'calculate_bpb')
graph.add_edge(START, 'calculate_boundary_percentage')

graph.add_edge('calculate_sr', 'summary1')
graph.add_edge('calculate_bpb', 'summary1')
graph.add_edge('calculate_boundary_percentage', 'summary1')
graph.add_edge('summary1', END)
workflow = graph.compile()

# %%
from IPython.display import Image
Image(workflow.get_graph().draw_mermaid_png())

# %%
initial_state = {'runs':100,
                 'balls':50,
                 'fours':6,
                 'sixes':4
                }
workflow.invoke(initial_state)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 6
#       1 initial_state = {'runs':100,
#       2                  'balls':50,
#       3                  'fours':6,
#       4                  'sixes':4
#       5                 }
# ----> 6 workflow.invoke(initial_state)
#
# File ~/miniforge3/envs/anomaly/lib/python3.12/site-packages/langgraph/pregel/__init__.py:2795, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, **kwargs)
#    2793 else:
#    2794     chunks = []
# -> 2795 for chunk in self.stream(
#    2796     input,
#    2797     config,
#    2798     stream_mode=stream_mode,
#    2799     output_keys=output_keys,
#    2800     interrupt_before=interrupt_before,
#    2801     interrupt_after=interrupt_after,
#    2802     checkpoint_during=checkpoint_during,
# ...
